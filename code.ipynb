# %% [markdown]
# <a href="https://colab.research.google.com/github/orannahum/16-QAM_K-means_clustering/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n_samples = 50000
n_bins = 16
  # use 3 bins for calibration_curve as we have 3 clusters here

# Generate 3 blobs with 2 classes where the second blob contains
# half positive samples and half negative samples. Probability in this
# blob is therefore 0.5.
centers = [[10, 10],
           [10, -10],
           [-10,10],
           [-10,-10],
           [-30,-30],
           [-30,-10],
           [-30,10],
           [-30,30],
           [-10,30],
           [-10,-30],
           [10,30],
           [10,-30],
           [30,30],
           [30,10],
           [30,-10],
           [30,-30]]
dataset = make_blobs(n_samples=n_samples, centers=centers, shuffle=False)
points=dataset[0]

# %%
kmeans.fit(points)
# Out:
# KMeans(n_clusters=16)

# %%
plt.scatter(dataset[0][:,0],dataset[0][:,1])
plt.title("16-qam constellation with random noise")
plt.xlabel("I")
plt.ylabel("Q")
plt.show()

# %%
clusters=kmeans.cluster_centers_

# %%
print(clusters)
# Out:
# [[-10.0197881  -29.9809111 ]
#  [ 10.01309313   9.97262033]
#  [-29.9806621   30.01093508]
#  [ 29.97035331 -10.00584574]
#  [-10.00305438  -9.94187285]
#  [-29.9660826    9.99557788]
#  [ 29.99785974  30.02376568]
#  [-29.97326485 -29.99484993]
#  [  9.98741954 -30.00658367]
#  [  9.99263509  30.01059365]
#  [-10.00187436  30.00587184]
#  [ 29.98622075   9.97886377]
#  [ 29.98857383 -29.99019886]
#  [ 10.02269598  -9.98267187]
#  [-10.0093321    9.99452967]
#  [-30.00722244  -9.97375775]]

# %%
y_km=kmeans.fit_predict(points)

# %%
plt.scatter(points[y_km==0,0],points[y_km==0,1],s=50,color='b')
plt.scatter(points[y_km==1,0],points[y_km==1,1],s=50,color='orange')
plt.scatter(points[y_km==2,0],points[y_km==2,1],s=50,color='g')
plt.scatter(points[y_km==3,0],points[y_km==3,1],s=50,color='tomato')
plt.scatter(points[y_km==4,0],points[y_km==4,1],s=50,color='lime')
plt.scatter(points[y_km==5,0],points[y_km==5,1],s=50,color='red')
plt.scatter(points[y_km==6,0],points[y_km==6,1],s=50,color='y')
plt.scatter(points[y_km==7,0],points[y_km==7,1],s=50,color='aqua')
plt.scatter(points[y_km==8,0],points[y_km==8,1],s=50,color='Brown')
plt.scatter(points[y_km==9,0],points[y_km==9,1],s=50,color='deeppink')
plt.scatter(points[y_km==10,0],points[y_km==10,1],s=50,color='grey')
plt.scatter(points[y_km==11,0],points[y_km==11,1],s=50,color='gold')
plt.scatter(points[y_km==12,0],points[y_km==12,1],s=50,color='navy')
plt.scatter(points[y_km==13,0],points[y_km==13,1],s=50,color='chocolate')
plt.scatter(points[y_km==14,0],points[y_km==14,1],s=50,color='maroon')
plt.scatter(points[y_km==15,0],points[y_km==15,1],s=50,color='violet')
plt.scatter(clusters[0][0],clusters[0][1],marker='*',s=150,color='black')
plt.scatter(clusters[1][0],clusters[1][1],marker='*',s=150,color='black')
plt.scatter(clusters[2][0],clusters[2][1],marker='*',s=150,color='black')
plt.scatter(clusters[3][0],clusters[3][1],marker='*',s=150,color='black')
plt.scatter(clusters[4][0],clusters[4][1],marker='*',s=150,color='black')
plt.scatter(clusters[5][0],clusters[5][1],marker='*',s=150,color='black')
plt.scatter(clusters[6][0],clusters[6][1],marker='*',s=150,color='black')
plt.scatter(clusters[7][0],clusters[7][1],marker='*',s=150,color='black')
plt.scatter(clusters[8][0],clusters[8][1],marker='*',s=150,color='black')
plt.scatter(clusters[9][0],clusters[9][1],marker='*',s=150,color='black')
plt.scatter(clusters[10][0],clusters[10][1],marker='*',s=150,color='black')
plt.scatter(clusters[11][0],clusters[11][1],marker='*',s=150,color='black')
plt.scatter(clusters[12][0],clusters[12][1],marker='*',s=150,color='black')
plt.scatter(clusters[13][0],clusters[13][1],marker='*',s=150,color='black')
plt.scatter(clusters[14][0],clusters[14][1],marker='*',s=150,color='black')
plt.scatter(clusters[15][0],clusters[15][1],marker='*',s=150,color='black')
plt.title("16-qam K-means clustering")
plt.xlabel("I")
plt.ylabel("Q")
plt.show()
